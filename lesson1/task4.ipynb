# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(-np.pi, np.pi, 201)
plt.plot(x, np.cos(x))
plt.plot(x, np.cos(2*x))
plt.xlabel('x')
plt.ylabel('y')
plt.axis('tight')
plt.grid(True)
plt.show()
